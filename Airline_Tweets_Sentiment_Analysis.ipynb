# %% [markdown]
# # Importing required libraries to load the dataset and for data cleaning

# %% [markdown]
# The dataset used for the training of the model is airline-tweets. The dataset contains the tweets written by passengers who took a flight and gave their experience about the airline service. The dataset's target feature is airline_sentiment which is used for rating prediction. Airline_sentiment has three ratings - Negative, Neutral and Positive, which are to be label encoded into numbers being represented as 0,1,2.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import pandas as pd
df = pd.read_csv('Tweets.csv')

# %%
df
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 1                         NaN                     0.0000  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# ...                       ...                        ...             ...
# 14635                     NaN                     0.0000        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold             name negativereason_gold  \
# 0                        NaN          cairdin                 NaN
# 1                        NaN         jnardino                 NaN
# 2                        NaN       yvonnalynn                 NaN
# 3                        NaN         jnardino                 NaN
# 4                        NaN         jnardino                 NaN
# ...                      ...              ...                 ...
# 14635                    NaN  KristenReenders                 NaN
# 14636                    NaN         itsropes                 NaN
# 14637                    NaN         sanyabun                 NaN
# 14638                    NaN       SraJackson                 NaN
# 14639                    NaN        daviddtwu                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 1                  0  @VirginAmerica plus you've added commercials t...
# 2                  0  @VirginAmerica I didn't today... Must mean I n...
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# ...              ...                                                ...
# 14635              0  @AmericanAir thank you we got on a different f...
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
# 14639              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 1             NaN  2015-02-24 11:15:59 -0800            NaN
# 2             NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# ...           ...                        ...            ...
# 14635         NaN  2015-02-22 12:01:01 -0800            NaN
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone
# 0      Eastern Time (US & Canada)
# 1      Pacific Time (US & Canada)
# 2      Central Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4      Pacific Time (US & Canada)
# ...                           ...
# 14635                         NaN
# 14636                         NaN
# 14637                         NaN
# 14638  Eastern Time (US & Canada)
# 14639                         NaN
#
# [14640 rows x 15 columns]

# %% [markdown]
# # Removing unwanted columns to reduce the size of the dataset

# %% [markdown]
# By removing the unwanted columns, it gets easier to work and clean the dataset. Moreover it also helps in increasing the model accuracy. The required columns are- airline_sentiment, airline_sentiment_confidence, text.

# %%
df.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df = df[['airline_sentiment', 'airline_sentiment_confidence','text']]

# %%
df.shape
# Out:
# (14640, 3)

# %% [markdown]
# # Selecting the cells which have 'airline_sentiment_confidence' greater then 0.9 so as to increase the accuracy of the model

# %%
df[df['airline_sentiment_confidence'] > 0.9].shape
# Out:
# (10458, 3)

# %%
df = df[df['airline_sentiment_confidence'] > 0.9]

# %%
df
# Out:
#       airline_sentiment  airline_sentiment_confidence  \
# 0               neutral                           1.0
# 3              negative                           1.0
# 4              negative                           1.0
# 5              negative                           1.0
# 9              positive                           1.0
# ...                 ...                           ...
# 14631          negative                           1.0
# 14633          negative                           1.0
# 14636          negative                           1.0
# 14637           neutral                           1.0
# 14638          negative                           1.0
#
#                                                     text
# 0                    @VirginAmerica What @dhepburn said.
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
# 5      @VirginAmerica seriously would pay $30 a fligh...
# 9      @VirginAmerica it was amazing, and arrived an ...
# ...                                                  ...
# 14631  @AmericanAir thx for nothing on getting us out...
# 14633  @AmericanAir my flight was Cancelled Flightled...
# 14636  @AmericanAir leaving over 20 minutes Late Flig...
# 14637  @AmericanAir Please bring American Airlines to...
# 14638  @AmericanAir you have my money, you change my ...
#
# [10458 rows x 3 columns]

# %%
list_of_stopwords = stopwords.words('English')

# %% [markdown]
# # Writing a for loop to reduce the complexity of the tweets

# %% [markdown]
# A for loop is written to eliminate the unwanted words. The loop removes special characters and airline names used in the tweets as they are of no use. Moreover, all the stopwords are also removed to reduce the complexity of the model. After removing the unwanted words, the remaining words are appended into a new column named clean_tweet.

# %%
clean_tweets_list = []
airline_names = ['virginamerica', 'jetblue', 'united', 'americanair', 'usairways']
special_characters = ['|', '@', '#', '$', '%', '^', '&', '*', ':']
for i in range(df.shape[0]):
    current_tweet = df['text'].values[i]
    list_of_words = word_tokenize(current_tweet)
    clean_tweet = ''
    for each_word in list_of_words:
        each_word = each_word.lower()
        if not each_word in list_of_stopwords:
            if not each_word in airline_names:
                if not each_word in special_characters:
                    clean_tweet = clean_tweet + '' + each_word
    clean_tweets_list.append(clean_tweet)

# %%
df['clean_tweets'] = clean_tweets_list

# %%
df.head(60)
# Out:
#    airline_sentiment  airline_sentiment_confidence  \
# 0            neutral                           1.0
# 3           negative                           1.0
# 4           negative                           1.0
# 5           negative                           1.0
# 9           positive                           1.0
# 11          positive                           1.0
# 12          positive                           1.0
# 14          positive                           1.0
# 16          positive                           1.0
# 17          negative                           1.0
# 18          positive                           1.0
# 19          positive                           1.0
# 21          positive                           1.0
# 22          positive                           1.0
# 23           neutral                           1.0
# 24          negative                           1.0
# 25          negative                           1.0
# 26          negative                           1.0
# 28          negative                           1.0
# 30          negative                           1.0
# 31           neutral                           1.0
# 32          negative                           1.0
# 33          negative                           1.0
# 34          positive                           1.0
# 36          positive                           1.0
# 37          positive                           1.0
# 39          negative                           1.0
# 42           neutral                           1.0
# 44           neutral                           1.0
# 45          positive                           1.0
# 47          positive                           1.0
# 48           neutral                           1.0
# 52           neutral                           1.0
# 54           neutral                           1.0
# 56          positive                           1.0
# 59           neutral                           1.0
# 60           neutral                           1.0
# 61          negative                           1.0
# 63           neutral                           1.0
# 64          positive                           1.0
# 66          negative                           1.0
# 67          negative                           1.0
# 69          negative                           1.0
# 70           neutral                           1.0
# 72           neutral                           1.0
# 73          negative                           1.0
# 74          positive                           1.0
# 75          positive                           1.0
# 76           neutral                           1.0
# 77           neutral                           1.0
# 78          negative                           1.0
# 79           neutral                           1.0
# 80          negative                           1.0
# 81          positive                           1.0
# 83          negative                           1.0
# 84          negative                           1.0
# 85          negative                           1.0
# 87           neutral                           1.0
# 89          negative                           1.0
# 90           neutral                           1.0
#
#                                                  text  \
# 0                 @VirginAmerica What @dhepburn said.
# 3   @VirginAmerica it's really aggressive to blast...
# 4   @VirginAmerica and it's a really big bad thing...
# 5   @VirginAmerica seriously would pay $30 a fligh...
# 9   @VirginAmerica it was amazing, and arrived an ...
# 11  @VirginAmerica I &lt;3 pretty graphics. so muc...
# 12  @VirginAmerica This is such a great deal! Alre...
# 14                             @VirginAmerica Thanks!
# 16  @VirginAmerica So excited for my first cross c...
# 17  @VirginAmerica  I flew from NYC to SFO last we...
# 18                    I ❤️ flying @VirginAmerica. ☺️👍
# 19  @VirginAmerica you know what would be amazingl...
# 21  @VirginAmerica I love this graphic. http://t.c...
# 22  @VirginAmerica I love the hipster innovation. ...
# 23  @VirginAmerica will you be making BOS&gt;LAS n...
# 24  @VirginAmerica you guys messed up my seating.....
# 25  @VirginAmerica status match program.  I applie...
# 26  @VirginAmerica What happened 2 ur vegan food o...
# 28  @VirginAmerica amazing to me that we can't get...
# 30  @VirginAmerica hi! I just bked a cool birthday...
# 31  @VirginAmerica Are the hours of operation for ...
# 32  @VirginAmerica help, left expensive headphones...
# 33  @VirginAmerica awaiting my return phone call, ...
# 34  @VirginAmerica this is great news!  America co...
# 36  @VirginAmerica Moodlighting is the only way to...
# 37  @VirginAmerica @freddieawards Done and done! B...
# 39  @VirginAmerica Your chat support is not workin...
# 42  @VirginAmerica plz help me win my bid upgrade ...
# 44  @VirginAmerica are flights leaving Dallas for ...
# 45  @VirginAmerica I'm #elevategold for a good rea...
# 47          @VirginAmerica wow this just blew my mind
# 48  @VirginAmerica @ladygaga @carrieunderwood Afte...
# 52  @VirginAmerica wish you flew out of Atlanta......
# 54  @VirginAmerica Will flights be leaving Dallas ...
# 56  @VirginAmerica you know it. Need it on my spot...
# 59  @VirginAmerica New marketing song? https://t.c...
# 60  @VirginAmerica @ladygaga @carrieunderwood Juli...
# 61  @VirginAmerica I called a 3-4 weeks ago about ...
# 63  @VirginAmerica @LadyGaga @CarrieUnderwood Sorr...
# 64  @VirginAmerica @ladygaga @carrieunderwood  lov...
# 66  @VirginAmerica heyyyy guyyyys.. been trying to...
# 67  @VirginAmerica Hi, Virgin! I'm on hold for 40-...
# 69  @VirginAmerica everything was fine until you l...
# 70  @virginamerica Need to change reservation. Hav...
# 72  @VirginAmerica hi I just booked a flight but n...
# 73  @VirginAmerica your airline is awesome but you...
# 74  @VirginAmerica not worried, it's been a great ...
# 75  @VirginAmerica awesome. I flew yall Sat mornin...
# 76  @VirginAmerica Or watch some of the best stude...
# 77  @VirginAmerica first time flying you all. do y...
# 78  @VirginAmerica what is going on with customer ...
# 79             @VirginAmerica what happened to Doom?!
# 80  @VirginAmerica why can't you supp the biz trav...
# 81  @VirginAmerica I've applied more then once to ...
# 83  @VirginAmerica I have no interesting flying wi...
# 84  @VirginAmerica it was a disappointing experien...
# 85  @VirginAmerica I’m having trouble adding this ...
# 87  @VirginAmerica Random Q: what's the distributi...
# 89  @VirginAmerica Why is the site down?  When wil...
# 90  @VirginAmerica "You down with RNP?" "Yeah you ...
#
#                                          clean_tweets
# 0                                       dhepburnsaid.
# 3   'sreallyaggressiveblastobnoxious``entertainmen...
# 4                                 'sreallybigbadthing
# 5   seriouslywouldpay30flightseatsn'tplaying.'srea...
# 9                   amazing,arrivedhourearly.'regood.
# 11   lt;3prettygraphics.muchbetterminimaliconography.
# 12  greatdeal!alreadythinking2ndtripaustraliaamp;n...
# 14                                            thanks!
# 16  excitedfirstcrosscountryflightlaxmco'veheardno...
# 17  flewnycsfolastweekcouldn'tfullysitseatduetwola...
# 18                                       ❤️flying.☺️👍
# 19  knowwouldamazinglyawesome?bos-fllplease!!!!!!!...
# 21                  lovegraphic.http//t.co/ut5grrwaaa
# 22               lovehipsterinnovation.feelgoodbrand.
# 23      makingbosgt;lasnonstoppermanentlyanytimesoon?
# 24  guysmessedseating..reservedseatingfriendsguysg...
# 25  statusmatchprogram.applied'sthreeweeks.callede...
# 26  happened2urveganfoodoptions?!leastsayursitekno...
# 28  amazingcan'tgetcoldairvents.vx358noairworstfli...
# 30  hi!bkedcoolbirthdaytrip,can'taddelevate.causee...
# 31          hoursoperationclubsfopostedonlinecurrent?
# 32  help,leftexpensiveheadphonesflight89iadlaxtoda...
# 33  awaitingreturnphonecall,wouldpreferuseonlinese...
# 34  greatnews!americacouldstartflightshawaiiendyea...
# 36  moodlightingwayfly!bestexperienceever!coolcalm...
# 37     freddieawardsdonedone!bestairlinearound,hands!
# 39        chatsupportworkingsitehttp//t.co/vhp2gtdwpk
# 42  plzhelpwinbidupgradeflight2/27lax---gt;sea!!!🍷...
# 44              flightsleavingdallasseattletimefeb24?
# 45                      'melevategoldgoodreasonrock!!
# 47                                        wowblewmind
# 48  ladygagacarrieunderwoodlastnighttributesoundof...
# 52                            wishflewatlanta...soon?
# 54                flightsleavingdallaslafebruary24th?
# 56                know.needspotifystatguiltypleasures
# 59  newmarketingsong?https//t.co/f2lfulcbq7letuskn...
# 60  ladygagacarrieunderwoodjulieandrewsfirstladyga...
# 61  called3-4weeksagoadding3flights2014elevate...s...
# 63      ladygagacarrieunderwoodsorry,marymartinfirst!
# 64  ladygagacarrieunderwoodlovethreereallycan'tbea...
# 66   heyyyyguyyyys..tryinggethour.someonecallplease?/
# 67  hi,virgin!'mhold40-50minutes--earlierflightsla...
# 69                              everythingfinelostbag
# 70  needchangereservation.virgincreditcard.needmod...
# 72                     hibookedflightneedaddbaggage,?
# 73  airlineawesomelaxloftneedsstepgame.40dirtytabl...
# 74  worried,'sgreatridenewplanegreatcrew.airlinesl...
# 75         awesome.flewyallsatmorning.waycorrectbill?
# 76  watchbeststudentfilmscountry35,000feet!cmfat35...
# 77  firsttimeflying.differentrate/policymediabags?...
# 78   goingcustomerservice?anywayspeakhumanasap?thank.
# 79                                     happeneddoom?!
# 80  can'tsuppbiztravelerlikesouthwestaircustomerse...
# 81  'veappliedmemberinflightcrewteam...im100intere...
# 83  interestingflying.cancelledflightnextfourfligh...
# 84  disappointingexperiencesharedeverybusinesstrav...
# 85  ’troubleaddingflightwifebookedelevateaccount.h...
# 87  randomq'sdistributionelevateavatars?betkittydi...
# 89                                         site?back?
# 90                              ``rnp?''``yeahknow!''

# %% [markdown]
# # Converting the tweets into a sparse matrix so as to train the model

# %% [markdown]
# Using sparse matrix to store data that contains a large number of zero-valued elements can both save a significant amount of memory and speed up the processing of that data.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
cv.fit(df['clean_tweets'])
# Out:
# CountVectorizer()

# %%
sparse_matrix = cv.transform(df['clean_tweets'])

# %%
sparse_matrix
# Out:
# <10458x24821 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31755 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Importing LabelEncoder to encode the rating

# %% [markdown]
# Label encoding the airline_sentiment column by replacing Negative, Neutral and Positive to be numbered as 0,1 and 2 respectively.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['airline_sentiment'] = le.fit_transform(df['airline_sentiment'])

# %%
df
# Out:
#        airline_sentiment  airline_sentiment_confidence  \
# 0                      1                           1.0
# 3                      0                           1.0
# 4                      0                           1.0
# 5                      0                           1.0
# 9                      2                           1.0
# ...                  ...                           ...
# 14631                  0                           1.0
# 14633                  0                           1.0
# 14636                  0                           1.0
# 14637                  1                           1.0
# 14638                  0                           1.0
#
#                                                     text  \
# 0                    @VirginAmerica What @dhepburn said.
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
# 5      @VirginAmerica seriously would pay $30 a fligh...
# 9      @VirginAmerica it was amazing, and arrived an ...
# ...                                                  ...
# 14631  @AmericanAir thx for nothing on getting us out...
# 14633  @AmericanAir my flight was Cancelled Flightled...
# 14636  @AmericanAir leaving over 20 minutes Late Flig...
# 14637  @AmericanAir Please bring American Airlines to...
# 14638  @AmericanAir you have my money, you change my ...
#
#                                             clean_tweets
# 0                                          dhepburnsaid.
# 3      'sreallyaggressiveblastobnoxious``entertainmen...
# 4                                    'sreallybigbadthing
# 5      seriouslywouldpay30flightseatsn'tplaying.'srea...
# 9                      amazing,arrivedhourearly.'regood.
# ...                                                  ...
# 14631  thxnothinggettinguscountrybackus.brokenplane?c...
# 14633  flightcancelledflightled,leavingtomorrowmornin...
# 14636  leaving20minuteslateflight.warningscommunicati...
# 14637            pleasebringamericanairlinesblackberry10
# 14638  money,changeflight,n'tanswerphones!suggestions...
#
# [10458 rows x 4 columns]

# %% [markdown]
# # Using train_test_split splitting the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(sparse_matrix , df['airline_sentiment'])

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((7843, 24821), (2615, 24821), (7843,), (2615,))

# %% [markdown]
# # Using MultinomialNB to train the model

# %% [markdown]
# Naive Bayes predict the tag of a text. They calculate the probability of each tag for a given text and then output the tag with the highest one.It is highly scalable with the number of predictors and data points. It is fast and can be used to make real-time predictions.It doesn't require as much training data

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nv = MultinomialNB()

# %%
nv.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# # Cheching the accuracy of the model

# %%
from sklearn.metrics import accuracy_score

# %%
Y_pred = nv.predict(X_test)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.682982791586998

# %% [markdown]
# # Testing the model

# %%
user_sentence = 'love it'

# %%
user_transformed_input = cv.transform([user_sentence])

# %%
nv.predict(user_transformed_input)
# Out:
# array([2])
